# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the input file and check the data dimension

# %%
gc = pd.read_csv('german_credit.csv')
gc.head()
# Out:
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# 3              radio/television           7882                 ... < 100 DM
# 4                     car (new)           4870                 ... < 100 DM
#
#     present_emp_since  installment_as_income_perc  \
# 0       .. >= 7 years                           4
# 1  1 <= ... < 4 years                           2
# 2  4 <= ... < 7 years                           2
# 3  4 <= ... < 7 years                           2
# 4  1 <= ... < 4 years                           3
#
#                    personal_status_sex  ... present_res_since  \
# 0                        male : single  ...                 4
# 1  female : divorced/separated/married  ...                 2
# 2                        male : single  ...                 3
# 3                        male : single  ...                 4
# 4                        male : single  ...                 4
#
#                                             property age  \
# 0                                        real estate  67
# 1                                        real estate  22
# 2                                        real estate  49
# 3  if not A121 : building society savings agreeme...  45
# 4                              unknown / no property  53
#
#    other_installment_plans   housing credits_this_bank  \
# 0                     none       own                 2
# 1                     none       own                 1
# 2                     none       own                 1
# 3                     none  for free                 1
# 4                     none  for free                 2
#
#                            job people_under_maintenance  \
# 0  skilled employee / official                        1
# 1  skilled employee / official                        1
# 2         unskilled - resident                        2
# 3  skilled employee / official                        2
# 4  skilled employee / official                        2
#
#                                    telephone foreign_worker
# 0  yes, registered under the customers name             yes
# 1                                       none            yes
# 2                                       none            yes
# 3                                       none            yes
# 4                                       none            yes
#
# [5 rows x 21 columns]

# %%
gc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
# default                       1000 non-null int64
# account_check_status          1000 non-null object
# duration_in_month             1000 non-null int64
# credit_history                1000 non-null object
# purpose                       1000 non-null object
# credit_amount                 1000 non-null int64
# savings                       1000 non-null object
# present_emp_since             1000 non-null object
# installment_as_income_perc    1000 non-null int64
# personal_status_sex           1000 non-null object
# other_debtors                 1000 non-null object
# present_res_since             1000 non-null int64
# property                      1000 non-null object
# age                           1000 non-null int64
# other_installment_plans       1000 non-null object
# housing                       1000 non-null object
# credits_this_bank             1000 non-null int64
# job                           1000 non-null object
# people_under_maintenance      1000 non-null int64
# telephone                     1000 non-null object
# foreign_worker                1000 non-null object
# dtypes: int64(8), object(13)
# memory usage: 113.3+ KB

# %%
gc.describe().transpose()
# Out:
#                              count      mean          std    min     25%  \
# default                     1000.0     0.300     0.458487    0.0     0.0
# duration_in_month           1000.0    20.903    12.058814    4.0    12.0
# credit_amount               1000.0  3271.258  2822.736876  250.0  1365.5
# installment_as_income_perc  1000.0     2.973     1.118715    1.0     2.0
# present_res_since           1000.0     2.845     1.103718    1.0     2.0
# age                         1000.0    35.546    11.375469   19.0    27.0
# credits_this_bank           1000.0     1.407     0.577654    1.0     1.0
# people_under_maintenance    1000.0     1.155     0.362086    1.0     1.0
#
#                                50%      75%      max
# default                        0.0     1.00      1.0
# duration_in_month             18.0    24.00     72.0
# credit_amount               2319.5  3972.25  18424.0
# installment_as_income_perc     3.0     4.00      4.0
# present_res_since              3.0     4.00      4.0
# age                           33.0    42.00     75.0
# credits_this_bank              1.0     2.00      4.0
# people_under_maintenance       1.0     1.00      2.0

# %%
print("Dimension of data:", gc.shape)
print("Dimension of dataframe:", gc.ndim)
# Out:
# Dimension of data: (1000, 21)
# Dimension of dataframe: 2

# %% [markdown]
# ### Q1 Randomly select 50% data for this use case( 1 Marks)
# ###### Hint: Use train_test_split

# %%
from sklearn.model_selection import train_test_split
gc_h1, gc_h2 = train_test_split(gc, test_size=0.5, random_state = 5)
gc_h1.head()
# Out:
#      default                               account_check_status  \
# 34         0  >= 200 DM / salary assignments for at least 1 ...
# 552        1                                             < 0 DM
# 170        1                                             < 0 DM
# 466        1                                             < 0 DM
# 713        0                                             < 0 DM
#
#      duration_in_month                                     credit_history  \
# 34                  12           existing credits paid back duly till now
# 552                 48           existing credits paid back duly till now
# 170                 15       no credits taken/ all credits paid back duly
# 466                 24                    delay in paying off in the past
# 713                  9  critical account/ other credits existing (not ...
#
#                  purpose  credit_amount       savings   present_emp_since  \
# 34      radio/television           1474  ... < 100 DM       ... < 1 year
# 552  domestic appliances           6999  ... < 100 DM  4 <= ... < 7 years
# 170            car (new)            950  ... < 100 DM       .. >= 7 years
# 466  domestic appliances           1659  ... < 100 DM       ... < 1 year
# 713  domestic appliances           1138  ... < 100 DM  1 <= ... < 4 years
#
#      installment_as_income_perc                  personal_status_sex  ...  \
# 34                            4  female : divorced/separated/married  ...
# 552                           1               male : married/widowed  ...
# 170                           4                        male : single  ...
# 466                           4  female : divorced/separated/married  ...
# 713                           4                        male : single  ...
#
#     present_res_since                                           property age  \
# 34                  1  if not A121 : building society savings agreeme...  33
# 552                 1                                        real estate  34
# 170                 3  if not A121/A122 : car or other, not in attrib...  33
# 466                 2  if not A121/A122 : car or other, not in attrib...  29
# 713                 4                                        real estate  25
#
#      other_installment_plans housing credits_this_bank  \
# 34                      bank     own                 1
# 552                     none     own                 2
# 170                     none    rent                 2
# 466                     none    rent                 1
# 713                     none     own                 2
#
#                                                    job  \
# 34   management/ self-employed/ highly qualified em...
# 552                        skilled employee / official
# 170                        skilled employee / official
# 466                               unskilled - resident
# 713                               unskilled - resident
#
#     people_under_maintenance                                  telephone  \
# 34                         1  yes, registered under the customers name
# 552                        1  yes, registered under the customers name
# 170                        2                                       none
# 466                        1  yes, registered under the customers name
# 713                        1                                       none
#
#     foreign_worker
# 34             yes
# 552            yes
# 170            yes
# 466            yes
# 713            yes
#
# [5 rows x 21 columns]

# %%
gc_h1.shape
# Out:
# (500, 21)

# %% [markdown]
# ### Q2.Prepare the model data by converting non-numeric to dummy ( 1 Marks)
# ##### Hint: Use get_dummies

# %%
object_list = list(gc_h1.select_dtypes(include ='object').columns)
gc_h1 = pd.get_dummies(gc_h1, columns=object_list)

# %%
gc_h1.shape
# Out:
# (500, 62)

# %% [markdown]
# ### Check for highly correlated variables but don't required any treatment for this use case

# %%
gc_h1.corr()
# Out:
#                                                      default  \
# default                                             1.000000
# duration_in_month                                   0.232277
# credit_amount                                       0.213898
# installment_as_income_perc                          0.072558
# present_res_since                                   0.024307
# age                                                 0.014624
# credits_this_bank                                  -0.017988
# people_under_maintenance                            0.002662
# account_check_status_0 <= ... < 200 DM              0.139863
# account_check_status_< 0 DM                         0.273193
# account_check_status_>= 200 DM / salary assignm... -0.095161
# account_check_status_no checking account           -0.334860
# credit_history_all credits at this bank paid ba...  0.125372
# credit_history_critical account/ other credits ... -0.194729
# credit_history_delay in paying off in the past      0.052281
# credit_history_existing credits paid back duly ...  0.044545
# credit_history_no credits taken/ all credits pa...  0.130901
# purpose_(vacation - does not exist?)                0.083351
# purpose_business                                    0.045887
# purpose_car (new)                                   0.035695
# purpose_car (used)                                 -0.061156
# purpose_domestic appliances                        -0.076980
# purpose_education                                   0.052775
# purpose_furniture/equipment                         0.026074
# purpose_radio/television                            0.000088
# purpose_repairs                                    -0.014560
# purpose_retraining                                 -0.062455
# savings_.. >= 1000 DM                              -0.076326
# savings_... < 100 DM                                0.165145
# savings_100 <= ... < 500 DM                         0.032937
# ...                                                      ...
# present_emp_since_.. >= 7 years                    -0.055366
# present_emp_since_... < 1 year                      0.105522
# present_emp_since_1 <= ... < 4 years                0.044262
# present_emp_since_4 <= ... < 7 years               -0.135188
# present_emp_since_unemployed                        0.057851
# personal_status_sex_female : divorced/separated...  0.069086
# personal_status_sex_male : divorced/separated       0.090083
# personal_status_sex_male : married/widowed         -0.019328
# personal_status_sex_male : single                  -0.097260
# other_debtors_co-applicant                          0.086087
# other_debtors_guarantor                            -0.024382
# other_debtors_none                                 -0.032473
# property_if not A121 : building society savings... -0.029982
# property_if not A121/A122 : car or other, not i...  0.041310
# property_real estate                               -0.166223
# property_unknown / no property                      0.180580
# other_installment_plans_bank                        0.109620
# other_installment_plans_none                       -0.117684
# other_installment_plans_stores                      0.036217
# housing_for free                                    0.139864
# housing_own                                        -0.187481
# housing_rent                                        0.106795
# job_management/ self-employed/ highly qualified...  0.124313
# job_skilled employee / official                    -0.097461
# job_unemployed/ unskilled - non-resident            0.002118
# job_unskilled - resident                            0.004079
# telephone_none                                      0.018460
# telephone_yes, registered under the customers n... -0.018460
# foreign_worker_no                                  -0.076642
# foreign_worker_yes                                  0.076642
#
#                                                     duration_in_month  \
# default                                                      0.232277
# duration_in_month                                            1.000000
# credit_amount                                                0.654040
# installment_as_income_perc                                   0.027427
# present_res_since                                            0.031647
# age                                                         -0.028739
# credits_this_bank                                           -0.012318
# people_under_maintenance                                    -0.088616
# account_check_status_0 <= ... < 200 DM                       0.119097
# account_check_status_< 0 DM                                 -0.029266
# account_check_status_>= 200 DM / salary assignm...          -0.064492
# account_check_status_no checking account                    -0.052160
# credit_history_all credits at this bank paid ba...           0.010384
# credit_history_critical account/ other credits ...          -0.095894
# credit_history_delay in paying off in the past               0.132989
# credit_history_existing credits paid back duly ...          -0.052697
# credit_history_no credits taken/ all credits pa...           0.163890
# purpose_(vacation - does not exist?)                        -0.013450
# purpose_business                                             0.142405
# purpose_car (new)                                           -0.101268
# purpose_car (used)                                           0.162162
# purpose_domestic appliances                                 -0.022215
# purpose_education                                           -0.019928
# purpose_furniture/equipment                                  0.113923
# purpose_radio/television                                    -0.089504
# purpose_repairs                                             -0.066668
# purpose_retraining                                          -0.093316
# savings_.. >= 1000 DM                                       -0.057130
# savings_... < 100 DM                                        -0.070710
# savings_100 <= ... < 500 DM                                  0.114659
# ...                                                               ...
# present_emp_since_.. >= 7 years                             -0.022239
# present_emp_since_... < 1 year                              -0.064343
# present_emp_since_1 <= ... < 4 years                         0.019088
# present_emp_since_4 <= ... < 7 years                         0.066323
# present_emp_since_unemployed                                 0.001359
# personal_status_sex_female : divorced/separated...          -0.064360
# personal_status_sex_male : divorced/separated               -0.001820
# personal_status_sex_male : married/widowed                  -0.058408
# personal_status_sex_male : single                            0.094448
# other_debtors_co-applicant                                   0.073847
# other_debtors_guarantor                                     -0.004556
# other_debtors_none                                          -0.041184
# property_if not A121 : building society savings...          -0.059666
# property_if not A121/A122 : car or other, not i...           0.105960
# property_real estate                                        -0.253202
# property_unknown / no property                               0.234867
# other_installment_plans_bank                                 0.025993
# other_installment_plans_none                                -0.030418
# other_installment_plans_stores                               0.013216
# housing_for free                                             0.212120
# housing_own                                                 -0.084126
# housing_rent                                                -0.080277
# job_management/ self-employed/ highly qualified...           0.175638
# job_skilled employee / official                              0.015190
# job_unemployed/ unskilled - non-resident                    -0.078192
# job_unskilled - resident                                    -0.153405
# telephone_none                                              -0.150134
# telephone_yes, registered under the customers n...           0.150134
# foreign_worker_no                                           -0.166076
# foreign_worker_yes                                           0.166076
#
#                                                     credit_amount  \
# default                                                  0.213898
# duration_in_month                                        0.654040
# credit_amount                                            1.000000
# installment_as_income_perc                              -0.252611
# present_res_since                                        0.047423
# age                                                      0.072994
# credits_this_bank                                        0.054255
# people_under_maintenance                                -0.047328
# account_check_status_0 <= ... < 200 DM                   0.150565
# account_check_status_< 0 DM                             -0.066205
# account_check_status_>= 200 DM / salary assignm...      -0.092983
# account_check_status_no checking account                -0.033688
# credit_history_all credits at this bank paid ba...      -0.000453
# credit_history_critical account/ other credits ...      -0.051913
# credit_history_delay in paying off in the past           0.092614
# credit_history_existing credits paid back duly ...      -0.067510
# credit_history_no credits taken/ all credits pa...       0.165012
# purpose_(vacation - does not exist?)                    -0.000660
# purpose_business                                         0.101436
# purpose_car (new)                                       -0.027852
# purpose_car (used)                                       0.252401
# purpose_domestic appliances                             -0.184189
# purpose_education                                       -0.028970
# purpose_furniture/equipment                              0.228634
# purpose_radio/television                                -0.060369
# purpose_repairs                                         -0.068348
# purpose_retraining                                      -0.077142
# savings_.. >= 1000 DM                                   -0.057445
# savings_... < 100 DM                                    -0.013581
# savings_100 <= ... < 500 DM                              0.056787
# ...                                                           ...
# present_emp_since_.. >= 7 years                         -0.011368
# present_emp_since_... < 1 year                          -0.057452
# present_emp_since_1 <= ... < 4 years                    -0.043863
# present_emp_since_4 <= ... < 7 years                     0.067150
# present_emp_since_unemployed                             0.094961
# personal_status_sex_female : divorced/separated...      -0.093712
# personal_status_sex_male : divorced/separated            0.048780
# personal_status_sex_male : married/widowed              -0.119556
# personal_status_sex_male : single                        0.132112
# other_debtors_co-applicant                               0.167696
# other_debtors_guarantor                                 -0.072195
# other_debtors_none                                      -0.043134
# property_if not A121 : building society savings...      -0.084422
# property_if not A121/A122 : car or other, not i...       0.079913
# property_real estate                                    -0.263099
# property_unknown / no property                           0.308138
# other_installment_plans_bank                             0.047784
# other_installment_plans_none                            -0.047291
# other_installment_plans_stores                           0.008403
# housing_for free                                         0.263845
# housing_own                                             -0.163430
# housing_rent                                            -0.028719
# job_management/ self-employed/ highly qualified...       0.380871
# job_skilled employee / official                         -0.140484
# job_unemployed/ unskilled - non-resident                -0.051385
# job_unskilled - resident                                -0.160887
# telephone_none                                          -0.268796
# telephone_yes, registered under the customers n...       0.268796
# foreign_worker_no                                       -0.089325
# foreign_worker_yes                                       0.089325
#
#                                                     installment_as_income_perc  \
# default                                                               0.072558
# duration_in_month                                                     0.027427
# credit_amount                                                        -0.252611
# installment_as_income_perc                                            1.000000
# present_res_since                                                     0.048169
# age                                                                   0.043957
# credits_this_bank                                                    -0.045177
# people_under_maintenance                                             -0.088518
# account_check_status_0 <= ... < 200 DM                               -0.045938
# account_check_status_< 0 DM                                           0.045556
# account_check_status_>= 200 DM / salary assignm...                   -0.086008
# account_check_status_no checking account                              0.040933
# credit_history_all credits at this bank paid ba...                    0.046299
# credit_history_critical account/ other credits ...                   -0.001244
# credit_history_delay in paying off in the past                       -0.035541
# credit_history_existing credits paid back duly ...                    0.012395
# credit_history_no credits taken/ all credits pa...                   -0.031736
# purpose_(vacation - does not exist?)                                 -0.011405
# purpose_business                                                     -0.011911
# purpose_car (new)                                                    -0.091408
# purpose_car (used)                                                   -0.062970
# purpose_domestic appliances                                           0.185380
# purpose_education                                                     0.062893
# purpose_furniture/equipment                                          -0.053455
# purpose_radio/television                                             -0.063214
# purpose_repairs                                                      -0.014564
# purpose_retraining                                                    0.025447
# savings_.. >= 1000 DM                                                 0.013606
# savings_... < 100 DM                                                 -0.019450
# savings_100 <= ... < 500 DM                                          -0.019109
# ...                                                                        ...
# present_emp_since_.. >= 7 years                                       0.109057
# present_emp_since_... < 1 year                                       -0.020022
# present_emp_since_1 <= ... < 4 years                                 -0.023650
# present_emp_since_4 <= ... < 7 years                                 -0.050172
# present_emp_since_unemployed                                         -0.044726
# personal_status_sex_female : divorced/separated...                   -0.021945
# personal_status_sex_male : divorced/separated                        -0.127454
# personal_status_sex_male : married/widowed                            0.007304
# personal_status_sex_male : single                                     0.079421
# other_debtors_co-applicant                                           -0.048721
# other_debtors_guarantor                                              -0.021759
# other_debtors_none                                                    0.047346
# property_if not A121 : building society savings...                    0.027272
# property_if not A121/A122 : car or other, not i...                    0.022270
# property_real estate                                                 -0.055077
# property_unknown / no property                                        0.007294
# other_installment_plans_bank                                         -0.053770
# other_installment_plans_none                                          0.005025
# other_installment_plans_stores                                        0.079319
# housing_for free                                                      0.010520
# housing_own                                                           0.069805
# housing_rent                                                         -0.093490
# job_management/ self-employed/ highly qualified...                    0.050609
# job_skilled employee / official                                       0.012890
# job_unemployed/ unskilled - non-resident                             -0.018606
# job_unskilled - resident                                             -0.055904
# telephone_none                                                       -0.033286
# telephone_yes, registered under the customers n...                    0.033286
# foreign_worker_no                                                    -0.096767
# foreign_worker_yes                                                    0.096767
#
#                                                     present_res_since  \
# default                                                      0.024307
# duration_in_month                                            0.031647
# credit_amount                                                0.047423
# installment_as_income_perc                                   0.048169
# present_res_since                                            1.000000
# age                                                          0.268706
# credits_this_bank                                            0.114518
# people_under_maintenance                                     0.048558
# account_check_status_0 <= ... < 200 DM                      -0.058353
# account_check_status_< 0 DM                                  0.120912
# account_check_status_>= 200 DM / salary assignm...          -0.103208
# account_check_status_no checking account                    -0.008819
# credit_history_all credits at this bank paid ba...           0.027073
# credit_history_critical account/ other credits ...           0.112964
# credit_history_delay in paying off in the past              -0.009637
# credit_history_existing credits paid back duly ...          -0.113639
# credit_history_no credits taken/ all credits pa...           0.004698
# purpose_(vacation - does not exist?)                         0.016965
# purpose_business                                            -0.052922
# purpose_car (new)                                            0.016335
# purpose_car (used)                                           0.097566
# purpose_domestic appliances                                 -0.033447
# purpose_education                                            0.026365
# purpose_furniture/equipment                                  0.063435
# purpose_radio/television                                    -0.039353
# purpose_repairs                                             -0.046640
# purpose_retraining                                          -0.006571
# savings_.. >= 1000 DM                                        0.025314
# savings_... < 100 DM                                        -0.076508
# savings_100 <= ... < 500 DM                                  0.011914
# ...                                                               ...
# present_emp_since_.. >= 7 years                              0.324735
# present_emp_since_... < 1 year                              -0.174467
# present_emp_since_1 <= ... < 4 years                        -0.135643
# present_emp_since_4 <= ... < 7 years                        -0.020360
# present_emp_since_unemployed                                -0.022245
# personal_status_sex_female : divorced/separated...           0.044760
# personal_status_sex_male : divorced/separated               -0.082350
# personal_status_sex_male : married/widowed                  -0.165760
# personal_status_sex_male : single                            0.096712
# other_debtors_co-applicant                                  -0.034797
# other_debtors_guarantor                                     -0.063559
# other_debtors_none                                           0.072936
# property_if not A121 : building society savings...          -0.100193
# property_if not A121/A122 : car or other, not i...          -0.053931
# property_real estate                                         0.015433
# property_unknown / no property                               0.162793
# other_installment_plans_bank                                 0.003818
# other_installment_plans_none                                 0.004588
# other_installment_plans_stores                              -0.014740
# housing_for free                                             0.227863
# housing_own                                                 -0.304161
# housing_rent                                                 0.172441
# job_management/ self-employed/ highly qualified...          -0.024081
# job_skilled employee / official                              0.018829
# job_unemployed/ unskilled - non-resident                    -0.033399
# job_unskilled - resident                                     0.010363
# telephone_none                                              -0.101722
# telephone_yes, registered under the customers n...           0.101722
# foreign_worker_no                                           -0.060475
# foreign_worker_yes                                           0.060475
#
#                                                          age  \
# default                                             0.014624
# duration_in_month                                  -0.028739
# credit_amount                                       0.072994
# installment_as_income_perc                          0.043957
# present_res_since                                   0.268706
# age                                                 1.000000
# credits_this_bank                                   0.141117
# people_under_maintenance                            0.105151
# account_check_status_0 <= ... < 200 DM             -0.086802
# account_check_status_< 0 DM                         0.022848
# account_check_status_>= 200 DM / salary assignm...  0.013922
# account_check_status_no checking account            0.052229
# credit_history_all credits at this bank paid ba...  0.064876
# credit_history_critical account/ other credits ...  0.172835
# credit_history_delay in paying off in the past      0.001922
# credit_history_existing credits paid back duly ... -0.187508
# credit_history_no credits taken/ all credits pa... -0.007070
# purpose_(vacation - does not exist?)                0.058889
# purpose_business                                    0.000060
# purpose_car (new)                                   0.040702
# purpose_car (used)                                  0.067409
# purpose_domestic appliances                         0.001193
# purpose_education                                   0.049302
# purpose_furniture/equipment                         0.057044
# purpose_radio/television                           -0.160754
# purpose_repairs                                    -0.068355
# purpose_retraining                                  0.032970
# savings_.. >= 1000 DM                               0.070257
# savings_... < 100 DM                               -0.013184
# savings_100 <= ... < 500 DM                        -0.083096
# ...                                                      ...
# present_emp_since_.. >= 7 years                     0.392050
# present_emp_since_... < 1 year                     -0.188751
# present_emp_since_1 <= ... < 4 years               -0.220504
# present_emp_since_4 <= ... < 7 years               -0.027725
# present_emp_since_unemployed                        0.056939
# personal_status_sex_female : divorced/separated... -0.132851
# personal_status_sex_male : divorced/separated       0.023484
# personal_status_sex_male : married/widowed         -0.139896
# personal_status_sex_male : single                   0.192708
# other_debtors_co-applicant                         -0.018419
# other_debtors_guarantor                            -0.024494
# other_debtors_none                                  0.031153
# property_if not A121 : building society savings... -0.009900
# property_if not A121/A122 : car or other, not i... -0.146299
# property_real estate                               -0.018225
# property_unknown / no property                      0.222667
# other_installment_plans_bank                        0.124975
# other_installment_plans_none                       -0.124184
# other_installment_plans_stores                      0.022898
# housing_for free                                    0.231645
# housing_own                                        -0.024398
# housing_rent                                       -0.169303
# job_management/ self-employed/ highly qualified...  0.086560
# job_skilled employee / official                    -0.135093
# job_unemployed/ unskilled - non-resident            0.049706
# job_unskilled - resident                            0.068617
# telephone_none                                     -0.147134
# telephone_yes, registered under the customers n...  0.147134
# foreign_worker_no                                  -0.017185
# foreign_worker_yes                                  0.017185
#
#                                                     credits_this_bank  \
# default                                                     -0.017988
# duration_in_month                                           -0.012318
# credit_amount                                                0.054255
# installment_as_income_perc                                  -0.045177
# present_res_since                                            0.114518
# age                                                          0.141117
# credits_this_bank                                            1.000000
# people_under_maintenance                                     0.109156
# account_check_status_0 <= ... < 200 DM                      -0.072384
# account_check_status_< 0 DM                                 -0.034471
# account_check_status_>= 200 DM / salary assignm...          -0.023522
# account_check_status_no checking account                     0.109340
# credit_history_all credits at this bank paid ba...          -0.088192
# credit_history_critical account/ other credits ...           0.497746
# credit_history_delay in paying off in the past               0.099493
# credit_history_existing credits paid back duly ...          -0.532867
# credit_history_no credits taken/ all credits pa...           0.140669
# purpose_(vacation - does not exist?)                        -0.046658
# purpose_business                                             0.186013
# purpose_car (new)                                            0.045890
# purpose_car (used)                                          -0.007927
# purpose_domestic appliances                                 -0.090981
# purpose_education                                            0.095390
# purpose_furniture/equipment                                  0.031863
# purpose_radio/television                                    -0.097210
# purpose_repairs                                             -0.063150
# purpose_retraining                                          -0.025016
# savings_.. >= 1000 DM                                        0.064584
# savings_... < 100 DM                                         0.063629
# savings_100 <= ... < 500 DM                                 -0.058622
# ...                                                               ...
# present_emp_since_.. >= 7 years                              0.129528
# present_emp_since_... < 1 year                              -0.119287
# present_emp_since_1 <= ... < 4 years                        -0.030092
# present_emp_since_4 <= ... < 7 years                        -0.008698
# present_emp_since_unemployed                                 0.022601
# personal_status_sex_female : divorced/separated...          -0.088093
# personal_status_sex_male : divorced/separated               -0.022740
# personal_status_sex_male : married/widowed                  -0.016972
# personal_status_sex_male : single                            0.102506
# other_debtors_co-applicant                                  -0.021486
# other_debtors_guarantor                                     -0.051480
# other_debtors_none                                           0.055003
# property_if not A121 : building society savings...          -0.027318
# property_if not A121/A122 : car or other, not i...           0.015193
# property_real estate                                        -0.002321
# property_unknown / no property                               0.013517
# other_installment_plans_bank                                 0.033458
# other_installment_plans_none                                -0.060803
# other_installment_plans_stores                               0.056893
# housing_for free                                             0.025675
# housing_own                                                  0.026888
# housing_rent                                                -0.054571
# job_management/ self-employed/ highly qualified...          -0.012096
# job_skilled employee / official                              0.015328
# job_unemployed/ unskilled - non-resident                     0.083657
# job_unskilled - resident                                    -0.035721
# telephone_none                                              -0.065252
# telephone_yes, registered under the customers n...           0.065252
# foreign_worker_no                                           -0.039526
# foreign_worker_yes                                           0.039526
#
#                                                     people_under_maintenance  \
# default                                                             0.002662
# duration_in_month                                                  -0.088616
# credit_amount                                                      -0.047328
# installment_as_income_perc                                         -0.088518
# present_res_since                                                   0.048558
# age                                                                 0.105151
# credits_this_bank                                                   0.109156
# people_under_maintenance                                            1.000000
# account_check_status_0 <= ... < 200 DM                             -0.051329
# account_check_status_< 0 DM                                         0.010843
# account_check_status_>= 200 DM / salary assignm...                 -0.006203
# account_check_status_no checking account                            0.040149
# credit_history_all credits at this bank paid ba...                  0.051385
# credit_history_critical account/ other credits ...                  0.025638
# credit_history_delay in paying off in the past                     -0.019277
# credit_history_existing credits paid back duly ...                 -0.056442
# credit_history_no credits taken/ all credits pa...                  0.050211
# purpose_(vacation - does not exist?)                                0.035233
# purpose_business                                                    0.058475
# purpose_car (new)                                                   0.133294
# purpose_car (used)                                                  0.025997
# purpose_domestic appliances                                        -0.081812
# purpose_education                                                   0.023512
# purpose_furniture/equipment                                        -0.003035
# purpose_radio/television                                           -0.143536
# purpose_repairs                                                    -0.038020
# purpose_retraining                                                  0.024513
# savings_.. >= 1000 DM                                              -0.042947
# savings_... < 100 DM                                               -0.025195
# savings_100 <= ... < 500 DM                                         0.032163
# ...                                                                      ...
# present_emp_since_.. >= 7 years                                     0.051790
# present_emp_since_... < 1 year                                     -0.028474
# present_emp_since_1 <= ... < 4 years                               -0.025142
# present_emp_since_4 <= ... < 7 years                               -0.006981
# present_emp_since_unemployed                                        0.010321
# personal_status_sex_female : divorced/separated...                 -0.195031
# personal_status_sex_male : divorced/separated                      -0.045233
# personal_status_sex_male : married/widowed                         -0.117283
# personal_status_sex_male : single                                   0.271039
# other_debtors_co-applicant                                          0.006406
# other_debtors_guarantor                                             0.044980
# other_debtors_none                                                 -0.040539
# property_if not A121 : building society savings...                 -0.003586
# property_if not A121/A122 : car or other, not i...                 -0.102084
# property_real estate                                                0.054181
# property_unknown / no property                                      0.070879
# other_installment_plans_bank                                        0.022468
# other_installment_plans_none                                       -0.036741
# other_installment_plans_stores                                      0.030672
# housing_for free                                                    0.076003
# housing_own                                                        -0.023277
# housing_rent                                                       -0.037070
# job_management/ self-employed/ highly qualified...                 -0.043847
# job_skilled employee / official                                    -0.138984
# job_unemployed/ unskilled - non-resident                            0.026481
# job_unskilled - resident                                            0.200835
# telephone_none                                                      0.076440
# telephone_yes, registered under the customers n...                 -0.076440
# foreign_worker_no                                                   0.141002
# foreign_worker_yes                                                 -0.141002
#
#                                                     account_check_status_0 <= ... < 200 DM  \
# default                                                                           0.139863
# duration_in_month                                                                 0.119097
# credit_amount                                                                     0.150565
# installment_as_income_perc                                                       -0.045938
# present_res_since                                                                -0.058353
# age                                                                              -0.086802
# credits_this_bank                                                                -0.072384
# people_under_maintenance                                                         -0.051329
# account_check_status_0 <= ... < 200 DM                                            1.000000
# account_check_status_< 0 DM                                                      -0.385042
# account_check_status_>= 200 DM / salary assignm...                               -0.151134
# account_check_status_no checking account                                         -0.494076
# credit_history_all credits at this bank paid ba...                               -0.024691
# credit_history_critical account/ other credits ...                               -0.121637
# credit_history_delay in paying off in the past                                    0.069217
# credit_history_existing credits paid back duly ...                                0.049607
# credit_history_no credits taken/ all credits pa...                                0.092626
# purpose_(vacation - does not exist?)                                             -0.055800
# purpose_business                                                                  0.114536
# purpose_car (new)                                                                -0.012164
# purpose_car (used)                                                               -0.058034
# purpose_domestic appliances                                                      -0.015385
# purpose_education                                                                 0.074059
# purpose_furniture/equipment                                                       0.116039
# purpose_radio/television                                                         -0.041199
# purpose_repairs                                                                  -0.055724
# purpose_retraining                                                               -0.005612
# savings_.. >= 1000 DM                                                             0.048616
# savings_... < 100 DM                                                             -0.041258
# savings_100 <= ... < 500 DM                                                       0.186804
# ...                                                                                    ...
# present_emp_since_.. >= 7 years                                                  -0.075309
# present_emp_since_... < 1 year                                                    0.040050
# present_emp_since_1 <= ... < 4 years                                             -0.017066
# present_emp_since_4 <= ... < 7 years                                              0.014516
# present_emp_since_unemployed                                                      0.087596
# personal_status_sex_female : divorced/separated...                               -0.002484
# personal_status_sex_male : divorced/separated                                    -0.003129
# personal_status_sex_male : married/widowed                                        0.121368
# personal_status_sex_male : single                                                -0.067172
# other_debtors_co-applicant                                                        0.077704
# other_debtors_guarantor                                                           0.062774
# other_debtors_none                                                               -0.098381
# property_if not A121 : building society savings...                               -0.084314
# property_if not A121/A122 : car or other, not i...                                0.038062
# property_real estate                                                              0.001926
# property_unknown / no property                                                    0.042188
# other_installment_plans_bank                                                      0.035711
# other_installment_plans_none                                                     -0.010252
# other_installment_plans_stores                                                   -0.039942
# housing_for free                                                                  0.016210
# housing_own                                                                      -0.013532
# housing_rent                                                                      0.002459
# job_management/ self-employed/ highly qualified...                                0.053099
# job_skilled employee / official                                                  -0.044877
# job_unemployed/ unskilled - non-resident                                          0.016722
# job_unskilled - resident                                                          0.000384
# telephone_none                                                                   -0.026229
# telephone_yes, registered under the customers n...                                0.026229
# foreign_worker_no                                                                -0.081100
# foreign_worker_yes                                                                0.081100
#
#                                                     account_check_status_< 0 DM  \
# default                                                                0.273193
# duration_in_month                                                     -0.029266
# credit_amount                                                         -0.066205
# installment_as_income_perc                                             0.045556
# present_res_since                                                      0.120912
# age                                                                    0.022848
# credits_this_bank                                                     -0.034471
# people_under_maintenance                                               0.010843
# account_check_status_0 <= ... < 200 DM                                -0.385042
# account_check_status_< 0 DM                                            1.000000
# account_check_status_>= 200 DM / salary assignm...                    -0.151134
# account_check_status_no checking account                              -0.494076
# credit_history_all credits at this bank paid ba...                     0.156267
# credit_history_critical account/ other credits ...                    -0.073544
# credit_history_delay in paying off in the past                        -0.113896
# credit_history_existing credits paid back duly ...                     0.058539
# credit_history_no credits taken/ all credits pa...                     0.003605
# purpose_(vacation - does not exist?)                                   0.048616
# purpose_business                                                      -0.124256
# purpose_car (new)                                                      0.052081
# purpose_car (used)                                                    -0.028273
# purpose_domestic appliances                                           -0.035495
# purpose_education                                                     -0.056787
# purpose_furniture/equipment                                            0.002052
# purpose_radio/television                                               0.108573
# purpose_repairs                                                       -0.005612
# purpose_retraining                                                    -0.005612
# savings_.. >= 1000 DM                                                 -0.097567
# savings_... < 100 DM                                                   0.223922
# savings_100 <= ... < 500 DM                                           -0.115235
# ...                                                                         ...
# present_emp_since_.. >= 7 years                                        0.026213
# present_emp_since_... < 1 year                                         0.063819
# present_emp_since_1 <= ... < 4 years                                  -0.026463
# present_emp_since_4 <= ... < 7 years                                  -0.057822
# present_emp_since_unemployed                                          -0.006391
# personal_status_sex_female : divorced/separated...                    -0.041305
# personal_status_sex_male : divorced/separated                          0.086772
# personal_status_sex_male : married/widowed                            -0.031604
# personal_status_sex_male : single                                      0.013391
# other_debtors_co-applicant                                            -0.038969
# other_debtors_guarantor                                                0.062774
# other_debtors_none                                                    -0.027450
# property_if not A121 : building society savings...                     0.089843
# property_if not A121/A122 : car or other, not i...                    -0.083452
# property_real estate                                                  -0.038202
# property_unknown / no property                                         0.054304
# other_installment_plans_bank                                           0.073014
# other_installment_plans_none                                          -0.099203
# other_installment_plans_stores                                         0.062473
# housing_for free                                                       0.044303
# housing_own                                                           -0.123139
# housing_rent                                                           0.110966
# job_management/ self-employed/ highly qualified...                    -0.020718
# job_skilled employee / official                                       -0.035620
# job_unemployed/ unskilled - non-resident                               0.050299
# job_unskilled - resident                                               0.045541
# telephone_none                                                         0.073330
# telephone_yes, registered under the customers n...                    -0.073330
# foreign_worker_no                                                      0.032805
# foreign_worker_yes                                                    -0.032805
#
#                                                     ...  housing_own  \
# default                                             ...    -0.187481
# duration_in_month                                   ...    -0.084126
# credit_amount                                       ...    -0.163430
# installment_as_income_perc                          ...     0.069805
# present_res_since                                   ...    -0.304161
# age                                                 ...    -0.024398
# credits_this_bank                                   ...     0.026888
# people_under_maintenance                            ...    -0.023277
# account_check_status_0 <= ... < 200 DM              ...    -0.013532
# account_check_status_< 0 DM                         ...    -0.123139
# account_check_status_>= 200 DM / salary assignm...  ...     0.015222
# account_check_status_no checking account            ...     0.118471
# credit_history_all credits at this bank paid ba...  ...    -0.015522
# credit_history_critical account/ other credits ...  ...     0.083162
# credit_history_delay in paying off in the past      ...     0.014016
# ...
# telephone_none                                            1.000000
# telephone_yes, registered under the customers n...       -1.000000
# foreign_worker_no                                         0.131605
# foreign_worker_yes                                       -0.131605
#
#                                                     telephone_yes, registered under the customers name   \
# default                                                                                     -0.018460
# duration_in_month                                                                            0.150134
# credit_amount                                                                                0.268796
# installment_as_income_perc                                                                   0.033286
# present_res_since                                                                            0.101722
# age                                                                                          0.147134
# credits_this_bank                                                                            0.065252
# people_under_maintenance                                                                    -0.076440
# account_check_status_0 <= ... < 200 DM                                                       0.026229
# account_check_status_< 0 DM                                                                 -0.073330
# account_check_status_>= 200 DM / salary assignm...                                           0.005220
# account_check_status_no checking account                                                     0.040841
# credit_history_all credits at this bank paid ba...                                          -0.015852
# credit_history_critical account/ other credits ...                                           0.029478
# credit_history_delay in paying off in the past                                               0.010554
# credit_history_existing credits paid back duly ...                                          -0.027795
# credit_history_no credits taken/ all credits pa...                                           0.004488
# purpose_(vacation - does not exist?)                                                        -0.000607
# purpose_business                                                                             0.117050
# purpose_car (new)                                                                           -0.056565
# purpose_car (used)                                                                           0.150031
# purpose_domestic appliances                                                                 -0.122663
# purpose_education                                                                           -0.077729
# purpose_furniture/equipment                                                                  0.106092
# purpose_radio/television                                                                    -0.015237
# purpose_repairs                                                                              0.014930
# purpose_retraining                                                                           0.014930
# savings_.. >= 1000 DM                                                                        0.018362
# savings_... < 100 DM                                                                        -0.050433
# savings_100 <= ... < 500 DM                                                                  0.005592
# ...                                                                                               ...
# present_emp_since_.. >= 7 years                                                              0.122111
# present_emp_since_... < 1 year                                                              -0.048901
# present_emp_since_1 <= ... < 4 years                                                        -0.093007
# present_emp_since_4 <= ... < 7 years                                                        -0.003022
# present_emp_since_unemployed                                                                 0.042003
# personal_status_sex_female : divorced/separated...                                          -0.066432
# personal_status_sex_male : divorced/separated                                                0.019696
# personal_status_sex_male : married/widowed                                                  -0.008976
# personal_status_sex_male : single                                                            0.056721
# other_debtors_co-applicant                                                                  -0.000424
# other_debtors_guarantor                                                                     -0.023646
# other_debtors_none                                                                           0.019522
# property_if not A121 : building society savings...                                          -0.056613
# property_if not A121/A122 : car or other, not i...                                           0.020648
# property_real estate                                                                        -0.098851
# property_unknown / no property                                                               0.155637
# other_installment_plans_bank                                                                 0.002620
# other_installment_plans_none                                                                -0.017997
# other_installment_plans_stores                                                               0.028838
# housing_for free                                                                             0.104291
# housing_own                                                                                 -0.017179
# housing_rent                                                                                -0.068729
# job_management/ self-employed/ highly qualified...                                           0.373200
# job_skilled employee / official                                                             -0.051189
# job_unemployed/ unskilled - non-resident                                                    -0.053740
# job_unskilled - resident                                                                    -0.261960
# telephone_none                                                                              -1.000000
# telephone_yes, registered under the customers n...                                           1.000000
# foreign_worker_no                                                                           -0.131605
# foreign_worker_yes                                                                           0.131605
#
#                                                     foreign_worker_no  \
# default                                                     -0.076642
# duration_in_month                                           -0.166076
# credit_amount                                               -0.089325
# installment_as_income_perc                                  -0.096767
# present_res_since                                           -0.060475
# age                                                         -0.017185
# credits_this_bank                                           -0.039526
# people_under_maintenance                                     0.141002
# account_check_status_0 <= ... < 200 DM                      -0.081100
# account_check_status_< 0 DM                                  0.032805
# account_check_status_>= 200 DM / salary assignm...           0.039063
# account_check_status_no checking account                     0.025971
# credit_history_all credits at this bank paid ba...          -0.047807
# credit_history_critical account/ other credits ...           0.037824
# credit_history_delay in paying off in the past              -0.059371
# credit_history_existing credits paid back duly ...           0.035123
# credit_history_no credits taken/ all credits pa...          -0.042740
# purpose_(vacation - does not exist?)                        -0.045835
# purpose_business                                            -0.041106
# purpose_car (new)                                            0.184089
# purpose_car (used)                                          -0.034021
# purpose_domestic appliances                                 -0.078163
# purpose_education                                           -0.035898
# purpose_furniture/equipment                                 -0.024323
# purpose_radio/television                                     0.008429
# purpose_repairs                                             -0.018331
# purpose_retraining                                          -0.018331
# savings_.. >= 1000 DM                                        0.049655
# savings_... < 100 DM                                         0.017561
# savings_100 <= ... < 500 DM                                 -0.038144
# ...                                                               ...
# present_emp_since_.. >= 7 years                             -0.051992
# present_emp_since_... < 1 year                               0.043473
# present_emp_since_1 <= ... < 4 years                         0.024063
# present_emp_since_4 <= ... < 7 years                         0.019846
# present_emp_since_unemployed                                -0.051571
# personal_status_sex_female : divorced/separated...          -0.090528
# personal_status_sex_male : divorced/separated               -0.013154
# personal_status_sex_male : married/widowed                   0.074143
# personal_status_sex_male : single                            0.046661
# other_debtors_co-applicant                                   0.034677
# other_debtors_guarantor                                      0.105498
# other_debtors_none                                          -0.107030
# property_if not A121 : building society savings...           0.042803
# property_if not A121/A122 : car or other, not i...          -0.107705
# property_real estate                                         0.127523
# property_unknown / no property                              -0.062049
# other_installment_plans_bank                                -0.057993
# other_installment_plans_none                                 0.077279
# other_installment_plans_stores                              -0.046829
# housing_for free                                            -0.073220
# housing_own                                                  0.035538
# housing_rent                                                 0.019846
# job_management/ self-employed/ highly qualified...          -0.059630
# job_skilled employee / official                             -0.034708
# job_unemployed/ unskilled - non-resident                    -0.027636
# job_unskilled - resident                                     0.106339
# telephone_none                                               0.131605
# telephone_yes, registered under the customers n...          -0.131605
# foreign_worker_no                                            1.000000
# foreign_worker_yes                                          -1.000000
#
#                                                     foreign_worker_yes
# default                                                       0.076642
# duration_in_month                                             0.166076
# credit_amount                                                 0.089325
# installment_as_income_perc                                    0.096767
# present_res_since                                             0.060475
# age                                                           0.017185
# credits_this_bank                                             0.039526
# people_under_maintenance                                     -0.141002
# account_check_status_0 <= ... < 200 DM                        0.081100
# account_check_status_< 0 DM                                  -0.032805
# account_check_status_>= 200 DM / salary assignm...           -0.039063
# account_check_status_no checking account                     -0.025971
# credit_history_all credits at this bank paid ba...            0.047807
# credit_history_critical account/ other credits ...           -0.037824
# credit_history_delay in paying off in the past                0.059371
# credit_history_existing credits paid back duly ...           -0.035123
# credit_history_no credits taken/ all credits pa...            0.042740
# purpose_(vacation - does not exist?)                          0.045835
# purpose_business                                              0.041106
# purpose_car (new)                                            -0.184089
# purpose_car (used)                                            0.034021
# purpose_domestic appliances                                   0.078163
# purpose_education                                             0.035898
# purpose_furniture/equipment                                   0.024323
# purpose_radio/television                                     -0.008429
# purpose_repairs                                               0.018331
# purpose_retraining                                            0.018331
# savings_.. >= 1000 DM                                        -0.049655
# savings_... < 100 DM                                         -0.017561
# savings_100 <= ... < 500 DM                                   0.038144
# ...                                                                ...
# present_emp_since_.. >= 7 years                               0.051992
# present_emp_since_... < 1 year                               -0.043473
# present_emp_since_1 <= ... < 4 years                         -0.024063
# present_emp_since_4 <= ... < 7 years                         -0.019846
# present_emp_since_unemployed                                  0.051571
# personal_status_sex_female : divorced/separated...            0.090528
# personal_status_sex_male : divorced/separated                 0.013154
# personal_status_sex_male : married/widowed                   -0.074143
# personal_status_sex_male : single                            -0.046661
# other_debtors_co-applicant                                   -0.034677
# other_debtors_guarantor                                      -0.105498
# other_debtors_none                                            0.107030
# property_if not A121 : building society savings...           -0.042803
# property_if not A121/A122 : car or other, not i...            0.107705
# property_real estate                                         -0.127523
# property_unknown / no property                                0.062049
# other_installment_plans_bank                                  0.057993
# other_installment_plans_none                                 -0.077279
# other_installment_plans_stores                                0.046829
# housing_for free                                              0.073220
# housing_own                                                  -0.035538
# housing_rent                                                 -0.019846
# job_management/ self-employed/ highly qualified...            0.059630
# job_skilled employee / official                               0.034708
# job_unemployed/ unskilled - non-resident                      0.027636
# job_unskilled - resident                                     -0.106339
# telephone_none                                               -0.131605
# telephone_yes, registered under the customers n...            0.131605
# foreign_worker_no                                            -1.000000
# foreign_worker_yes                                            1.000000
#
# [62 rows x 62 columns]

# %%
object_list
# Out:
# []

# %% [markdown]
# ### Drop the original variables which are converted to dummy

# %%
gc_h1.columns
# Original columns are already deleted from the list while converting them in dummy.
# Out:
# Index(['default', 'duration_in_month', 'credit_amount',
#        'installment_as_income_perc', 'present_res_since', 'age',
#        'credits_this_bank', 'people_under_maintenance',
#        'account_check_status_0 <= ... < 200 DM', 'account_check_status_< 0 DM',
#        'account_check_status_>= 200 DM / salary assignments for at least 1 year',
#        'account_check_status_no checking account',
#        'credit_history_all credits at this bank paid back duly',
#        'credit_history_critical account/ other credits existing (not at this bank)',
#        'credit_history_delay in paying off in the past',
#        'credit_history_existing credits paid back duly till now',
#        'credit_history_no credits taken/ all credits paid back duly',
#        'purpose_(vacation - does not exist?)', 'purpose_business',
#        'purpose_car (new)', 'purpose_car (used)',
#        'purpose_domestic appliances', 'purpose_education',
#        'purpose_furniture/equipment', 'purpose_radio/television',
#        'purpose_repairs', 'purpose_retraining', 'savings_.. >= 1000 DM ',
#        'savings_... < 100 DM', 'savings_100 <= ... < 500 DM',
#        'savings_500 <= ... < 1000 DM ', 'savings_unknown/ no savings account',
#        'present_emp_since_.. >= 7 years', 'present_emp_since_... < 1 year ',
#        'present_emp_since_1 <= ... < 4 years',
#        'present_emp_since_4 <= ... < 7 years', 'present_emp_since_unemployed',
#        'personal_status_sex_female : divorced/separated/married',
#        'personal_status_sex_male : divorced/separated',
#        'personal_status_sex_male : married/widowed',
#        'personal_status_sex_male : single', 'other_debtors_co-applicant',
#        'other_debtors_guarantor', 'other_debtors_none',
#        'property_if not A121 : building society savings agreement/ life insurance',
#        'property_if not A121/A122 : car or other, not in attribute 6',
#        'property_real estate', 'property_unknown / no property',
#        'other_installment_plans_bank', 'other_installment_plans_none',
#        'other_installment_plans_stores', 'housing_for free', 'housing_own',
#        'housing_rent',
#        'job_management/ self-employed/ highly qualified employee/ officer',
#        'job_skilled employee / official',
#        'job_unemployed/ unskilled - non-resident', 'job_unskilled - resident',
#        'telephone_none', 'telephone_yes, registered under the customers name ',
#        'foreign_worker_no', 'foreign_worker_yes'],
#       dtype='object')

# %% [markdown]
# ### Q3 Split Train/Test data 70:30 ratio( 1 Marks)
# ##### Hint:from sklearn.model_selection import train_test_split

# %%
# Splitting the dataframe into training and test set in the ratio of 70:30 
Y = gc_h1['default']
X = gc_h1.drop(['default'], axis = 1)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 9)

# %% [markdown]
# ### Q4 Build Random Forest Model( 1 Marks)
# #### Hint:from sklearn.ensemble import RandomForestClassifier using n_jobs=2,n_estimators=500,criterion="entropy",random_state=9999

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import model_selection
model = RandomForestClassifier(n_estimators = 500, n_jobs = 2, criterion = "entropy", random_state = 9999)
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)

# %% [markdown]
# ### Q5 Calculate Confusion Matrix and Accuracy score (1 Marks)
# ##### Hint: Use confusion_matrix and accuracy_score

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, roc_auc_score, precision_score, classification_report
print('Accuracy Score is: ', accuracy_score(Y_test, Y_pred))
print('Confusion Matrix is: ', confusion_matrix(Y_test, Y_pred))
# Out:
# Accuracy Score is:  0.76
# Confusion Matrix is:  [[92  6]
#  [30 22]]

# %% [markdown]
# ### Q6 Show the list of the features importance( 1 Marks)

# %%
print(model.feature_importances_)
# Out:
# [7.34974140e-02 8.83288501e-02 3.91086369e-02 3.53357569e-02
#  6.98347008e-02 2.06907879e-02 8.55736746e-03 1.63454985e-02
#  3.76156704e-02 7.24052996e-03 5.06922553e-02 8.73029286e-03
#  2.17842517e-02 9.07863092e-03 1.56442635e-02 1.03751533e-02
#  9.09461182e-03 1.03968116e-02 1.50741463e-02 1.00985770e-02
#  1.50383073e-02 7.33429777e-03 2.49788892e-03 1.43308843e-02
#  8.61287419e-04 7.87336276e-06 5.11715695e-03 1.75653696e-02
#  8.40470850e-03 6.51735883e-03 1.12100015e-02 1.35121358e-02
#  1.44781894e-02 1.82302082e-02 1.23828487e-02 7.48393449e-03
#  1.63913246e-02 8.75692621e-03 8.41154323e-03 2.02186680e-02
#  4.90346583e-03 4.57267868e-03 7.16707208e-03 1.30913267e-02
#  1.63892020e-02 1.76908290e-02 1.27370672e-02 1.52531189e-02
#  1.77800815e-02 5.43556913e-03 9.80079674e-03 2.23545927e-02
#  1.31787916e-02 1.31975308e-02 1.61564854e-02 1.05067340e-03
#  1.00135527e-02 1.35825627e-02 1.43276232e-02 2.45541314e-03
#  2.58644618e-03]

# %% [markdown]
# ### Q7 K-fold cross-validation( 2 Marks)
# ##### k-fold cross validation( without stratification)
# ##### Usually k is set as 10-20 in practical settings, depends on data set size

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score, cross_val_predict

# %%
# Use below values
num_folds = 10
seed = 77

# %%
#Validate the Random Forest model build above using k fold

models = []
models.append(('RF', RandomForestClassifier(n_estimators = 500, n_jobs = 2, criterion = "entropy", random_state = 9999)))


# evaluate  model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
    kfold = model_selection.KFold(n_splits=num_folds, random_state=seed)
    cv_results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    print(cv_results)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# [0.74 0.82 0.88 0.7  0.76 0.64 0.78 0.68 0.78 0.78]
# RF: 0.756000 (0.066212)

# %%
#Calculate Mean score
np.mean(results)
# Out:
# 0.756

# %%
# Calculate score standard deviation using std()
np.std(results)
# Out:
# 0.06621178142898738

# %% [markdown]
# # Q8 Print the confusion matrix( 1 Marks)

# %%
y_predict = cross_val_predict(RandomForestClassifier(n_estimators = 500, n_jobs = 2, criterion = "entropy", random_state = 9999), X, Y, cv=10)
print(confusion_matrix(Y, y_predict))
# Out:
# [[307  30]
#  [ 95  68]]

# %% [markdown]
# # Q9.Classification accuracy:
# percentage of correct predictions and Calculate sensitivity (or True Positive Rate or Recall) and Precision.
# ( 1 Marks)

# %%
print(accuracy_score(Y, y_predict))
print(precision_score(Y, y_predict))
print(classification_report(Y, y_predict))
# Out:
# 0.75
# 0.6938775510204082
#               precision    recall  f1-score   support
#
#            0       0.76      0.91      0.83       337
#            1       0.69      0.42      0.52       163
#
#    micro avg       0.75      0.75      0.75       500
#    macro avg       0.73      0.66      0.68       500
# weighted avg       0.74      0.75      0.73       500

# %% [markdown]
# # Q10.Plot Receiver Operating Characteristic (ROC) Curves( 1 Marks)

# %%
#Hint: Use roc_curve

# %%
fpr, tpr, thresholds = roc_curve(Y, y_predict)
print(fpr, tpr, thresholds)
# Out:
# [0.         0.08902077 1.        ] [0.         0.41717791 1.        ] [2 1 0]

# %%
lw =2
plt.plot(fpr,tpr)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ROC curve can help you to choose a threshold that balances sensitivity and specificity in a way that makes sense for your particular context

# %% [markdown]
# # Q11. Calculate AUC(the percentage of the ROC plot that is underneath the curve) - optional

# %% [markdown]
# ### Bootstrapping ( Bonus)
# ##### Given a dataset of size n, a bootstrap sample is created by sampling n instances uniformly from the data (with/without replacement)
# ##### Create a model with each bootstrap sample and validate it with the test set
# ##### Final result is calculated by averaging the accuracy of models

# %%
# Number of iterations for bootstrapping
bootstrap_iteration = 10
accuracy = []

# %%
from sklearn.utils import resample
from sklearn.metrics import accuracy_score

for i in range(bootstrap_iteration):
    X_, y_ = resample(X_train, y_train)
    rfm.fit(X_, y_)
    y_pred = rfm.predict(X_test)
    
    acc = accuracy_score(y_pred, y_test)
    accuracy.append(acc)

# %%
accuracy = np.array(accuracy)
print('Accuracy Score')
print('Avearge: ', accuracy.mean())
print('Standard deviation: ', accuracy.std())
# Out:
# Accuracy Score
# Avearge:  0.6893333333333334
# Standard deviation:  0.014966629547095768
